# %% [markdown]
# **Make a calculator using python with addition, substraction, multiplication,division and Power**

# %%
# Calculator

print("Calculator")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

# User se choice lena
choice = input("Enter choice (1/2/3/4/5): ")

# Numbers input lena
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == '1':
    print("Result:", num1 + num2)

elif choice == '2':
    print("Result:", num1 - num2)

elif choice == '3':
    print("Result:", num1 * num2)

elif choice == '4':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")

elif choice == '5':
    print("Result:", num1 ** num2)

else:
    print("Invalid input! Please select correct option.")
# Out:
# Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Enter choice (1/2/3/4/5):  5
# Enter first number:  6
# Enter second number:  3
# Result: 216.0

# %% [markdown]
# **write a program to check if there is any numeric value in list using for Loop**

# %%
# User se input lena (comma separated)
user_input = input("Enter list elements separated by comma: ")
my_list = user_input.split(",")

found_number = False

for item in my_list:
    item = item.strip()
    if item.replace('.', '', 1).isdigit():
        found_number = True
        break

if found_number:
    print("List contains a numeric value.")
else:
    print("List does not contain any numeric value.")
# Out:
# Enter list elements separated by comma:  0.003, key, true,cars
# List contains a numeric value.

# %% [markdown]
# **Write a python script to add a key to a dictionary.**

# %%
# Empty dictionary
my_dict = {}

# User se input lena
key = input("Enter key: ")
value = input("Enter value: ")

# Dictionary me add karna
my_dict[key] = value

print("Updated Dictionary:", my_dict)
# Out:
# Enter key:  Ali
# Enter value:  15
# Updated Dictionary: {'Ali': '15'}

# %% [markdown]
# **write a python program to sum all the numeric items in a dictionary.**

# %%
def sum_numeric_values(dictionary):
    total = 0
    for value in dictionary.values():
        if isinstance(value, (int, float)):
            total += value
    return total

# Example usage
my_dict = {
    "a": 45,
    "b": 67.5,
    "c": "hello",
    "d": 192,
    "e": [1, 2, 3]
}

result = sum_numeric_values(my_dict)
print("Sum of numeric values:", result)
# Out:
# Sum of numeric values: 304.5

# %% [markdown]
# **write a python program to identify duplicate values from list**

# %%
def find_duplicates(lst):
    seen = set()
    duplicates = set()
    
    for item in lst:
        if item in seen:
            duplicates.add(item)
        else:
            seen.add(item)
    
    return list(duplicates)

# Example usage
my_list = [6, 7, 3, 8, 2, 5, 7, 6, 3]

print("Duplicate values:", find_duplicates(my_list))
# Out:
# Duplicate values: [3, 6, 7]

# %% [markdown]
# **Write a python script to check if a given key already exist in a dictionary.**

# %%
# Function to check if a key exists in a dictionary
def check_key(dictionary, key):
    if key in dictionary:
        print(f"✅ Key '{key}' exists in the dictionary.")
    else:
        print(f"❌ Key '{key}' does not exist in the dictionary.")

# Example dictionary
my_dict = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}

# Take key input from user
key_to_check = input("Enter the key to check: ")

# Call the function
check_key(my_dict, key_to_check)
# Out:
# Enter the key to check:  city
# ✅ Key 'city' exists in the dictionary.
